# %%
import pandas as pd

# %%
df1 = pd.read_csv('201801-citibike-tripdata.csv')
df2 = pd.read_csv('201802-citibike-tripdata.csv')
df3 = pd.read_csv('201803-citibike-tripdata.csv')
df4 = pd.read_csv('201804-citibike-tripdata.csv')
df5 = pd.read_csv('201805-citibike-tripdata.csv')
df6 = pd.read_csv('201806-citibike-tripdata.csv')
df7 = pd.read_csv('201807-citibike-tripdata.csv')
df8 = pd.read_csv('201808-citibike-tripdata.csv')
df9 = pd.read_csv('201809-citibike-tripdata.csv')

# %%
df1['Month'] = 'January'
df2['Month'] = 'February'
df3['Month'] = 'March'
df4['Month'] = 'April'
df5['Month'] = 'May'
df6['Month'] = 'June'
df7['Month'] = 'July'
df8['Month'] = 'August'
df9['Month'] = 'September'

# %%
df3.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           500  2018-07-01 00:33:51.2640  2018-07-01 00:42:12.0280
# 1           455  2018-07-01 02:06:54.0270  2018-07-01 02:14:29.0900
# 2          1080  2018-07-01 02:09:16.4640  2018-07-01 02:27:17.0290
# 3           632  2018-07-01 02:55:04.5870  2018-07-01 03:05:36.7910
# 4          1676  2018-07-01 03:24:27.4350  2018-07-01 03:52:23.7760
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929            3236  W 42 St & Dyer Ave
# 1               -73.993929             529     W 42 St & 8 Ave
# 2               -73.993929             453     W 22 St & 8 Ave
# 3               -73.993929             465  Broadway & W 41 St
# 4               -73.993929            3425    2 Ave & E 104 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.758985             -73.993800   16583  Subscriber
# 1             40.757570             -73.990985   31481  Subscriber
# 2             40.744751             -73.999154   25004  Subscriber
# 3             40.755136             -73.986580   25867  Subscriber
# 4             40.789210             -73.943708   31351  Subscriber
#
#    birth year  gender Month
# 0        1981       1  July
# 1        1988       1  July
# 2        1982       2  July
# 3        1986       1  July
# 4        1992       1  July

# %%
df1.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df2.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df4.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df5.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df6.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df7.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df8.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
df9.rename(columns = {'tripduration': 'Trip Duration', 'starttime': 'Start Time', 
                      'stoptime':  'Stop Time', 'gender':'Gender', "usertype": "User Type",
                      'bikeid':'Bike ID' ,'birth year' : 'Birth Year', 'start station id': 'Start Station ID',
                      'start station name':'Start Station Name' ,'start station latitude' : 'Start Station Latitude',
                      'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 
                     'end station name' : 'End Station Name', 'end station latitude': 'End Station Latitude',
                     'end station longitude' : 'End Station Longitude'}, inplace = True)

# %%
citibike_2018_v2 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9])
citibike_2018_v2.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1            723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2            496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3            306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4            306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    Start Station Longitude  End Station ID         End Station Name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# 1               -73.993929          3255.0          8 Ave & W 31 St
# 2               -73.993929           525.0         W 34 St & 11 Ave
# 3               -73.993929           447.0          8 Ave & W 52 St
# 4               -73.993929          3356.0  Amsterdam Ave & W 66 St
#
#    End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 0             40.749013             -73.988484    31956  Subscriber
# 1             40.750585             -73.994685    32536  Subscriber
# 2             40.755942             -74.002116    16069  Subscriber
# 3             40.763707             -73.985162    31781  Subscriber
# 4             40.774667             -73.984706    30319  Subscriber
#
#    Birth Year  Gender    Month
# 0        1992       1  January
# 1        1969       1  January
# 2        1956       1  January
# 3        1974       1  January
# 4        1992       1  January

# %%
citibike_2018_v2.to_csv('citibike_2018_v2.csv', sep = ',')
